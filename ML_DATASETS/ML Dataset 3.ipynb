# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-31449ad6-5cb5-4d9e-9238-885c8f8fde34" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-31449ad6-5cb5-4d9e-9238-885c8f8fde34">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

# Replace 'your_file.csv' with the uploaded file name
Drone_data = pd.read_csv('ml_dataset3.csv')
Drone_data

# Display first 5 rows
Drone_data.head(5)
# Out:
#                                                 Name                Type  \
# 0  Zyamalox ZX drone with camera 4k ,12 MP ,fly 3...          Mini Drone
# 1  Fitpro M3 Ultra Beginner Drone 2.4G Mini FPV H...          Mini Drone
# 2  Clubmall E88 Pro 4K Camera Drone with WiFi FPV...  Professional Drone
# 3  Orivox A17 Aerial Drone with 4K Dual Camera - ...          Mini Drone
# 4  Orivox M3 Max Mini Drone with Pro Features HD ...          Mini Drone
#
#    Control Range             Battery Type  Weight    Price  Actual Price  \
# 0             40          Lithium Battery     200   2297.0        4999.0
# 1            300               AA Battery     500  10255.0       11000.0
# 2            102  AA Rechargeable Battery     150   1994.0        5999.0
# 3             50          Lithium Battery     150   2455.0        4999.0
# 4            200          Lithium Battery     200   4998.0        5999.0
#
#    Discount (%)
# 0          54.0
# 1           6.0
# 2          66.0
# 3          50.0
# ...

# %%
Drone_data.shape
# Out:
# (821, 8)

# %%
print("number of rows = ", Drone_data.shape[0])
# Out:
# number of rows =  821

# %%
print("number of columns = ", Drone_data.shape[1])
# Out:
# number of columns =  8

# %%
Drone_data.columns
# Out:
# Index(['Name', 'Type', 'Control Range', 'Battery Type', 'Weight', 'Price',
#        'Actual Price', 'Discount (%)'],
#       dtype='object')

# %%
Drone_data.dtypes
# Out:
# Name              object
# Type              object
# Control Range      int64
# Battery Type      object
# Weight             int64
# Price            float64
# Actual Price     float64
# Discount (%)     float64
# dtype: object

# %%
Drone_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 821 entries, 0 to 820
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Name           821 non-null    object
#  1   Type           821 non-null    object
#  2   Control Range  821 non-null    int64
#  3   Battery Type   821 non-null    object
#  4   Weight         821 non-null    int64
#  5   Price          813 non-null    float64
#  6   Actual Price   813 non-null    float64
#  7   Discount (%)   810 non-null    float64
# dtypes: float64(3), int64(2), object(3)
# memory usage: 51.4+ KB

# %%
Drone_data.columns
# Out:
# Index(['Name', 'Type', 'Control Range', 'Battery Type', 'Weight', 'Price',
#        'Actual Price', 'Discount (%)'],
#       dtype='object')

# %%
Drone_tab1 = Drone_data[['Name', 'Type','Price','Discount (%)']]
Drone_tab1.head(6)
# Out:
#                                                 Name                Type  \
# 0  Zyamalox ZX drone with camera 4k ,12 MP ,fly 3...          Mini Drone
# 1  Fitpro M3 Ultra Beginner Drone 2.4G Mini FPV H...          Mini Drone
# 2  Clubmall E88 Pro 4K Camera Drone with WiFi FPV...  Professional Drone
# 3  Orivox A17 Aerial Drone with 4K Dual Camera - ...          Mini Drone
# 4  Orivox M3 Max Mini Drone with Pro Features HD ...          Mini Drone
# 5  ERH India A17 Aerial Drone with 4K Dual Camera...          Mini Drone
#
#      Price  Discount (%)
# 0   2297.0          54.0
# 1  10255.0           6.0
# 2   1994.0          66.0
# 3   2455.0          50.0
# 4   4998.0          16.0
# 5   4376.0          27.0

# %%
Drone_data.columns
# Out:
# Index(['Name', 'Type', 'Control Range', 'Battery Type', 'Weight', 'Price',
#        'Actual Price', 'Discount (%)'],
#       dtype='object')

# %%
Drone_tab2 = Drone_data[['Name', 'Type', 'Control Range', 'Battery Type', 'Weight', 'Price',
       'Actual Price']]
Drone_tab2.head(2)
# Out:
#                                                 Name        Type  \
# 0  Zyamalox ZX drone with camera 4k ,12 MP ,fly 3...  Mini Drone
# 1  Fitpro M3 Ultra Beginner Drone 2.4G Mini FPV H...  Mini Drone
#
#    Control Range     Battery Type  Weight    Price  Actual Price
# 0             40  Lithium Battery     200   2297.0        4999.0
# 1            300       AA Battery     500  10255.0       11000.0

# %%
Drone_tab2.to_csv('Modified-Drone-dataset.csv')

# %%
Drone_tab3 = Drone_data.drop(columns=[ 'Control Range', 'Battery Type'], axis=1)
Drone_tab3
# Out:
#                                                   Name                Type  \
# 0    Zyamalox ZX drone with camera 4k ,12 MP ,fly 3...          Mini Drone
# 1    Fitpro M3 Ultra Beginner Drone 2.4G Mini FPV H...          Mini Drone
# 2    Clubmall E88 Pro 4K Camera Drone with WiFi FPV...  Professional Drone
# 3    Orivox A17 Aerial Drone with 4K Dual Camera - ...          Mini Drone
# 4    Orivox M3 Max Mini Drone with Pro Features HD ...          Mini Drone
# ..                                                 ...                 ...
# 816  Swa Mi Drone WiFi Camera Remote Control-Motion...  Professional Drone
# 817                              Radhikadro e449 Drone  Professional Drone
# 818  Mevara fOlDaBlE-ToY-DrOnE pHoToGrApHy GeStUrE-...  Professional Drone
# 819  mayuri E8 WiFi Camera Remote Control 360 Flip ...  Professional Drone
# 820  Swa Mi E88 Drone Best Adults/Kids Drone With W...  Professional Drone
#
#      Weight    Price  Actual Price  Discount (%)
# ...

# %%
Drone_tab3['Model'] = 'Drone Model'
Drone_tab3
# Out:
#                                                   Name                Type  \
# 0    Zyamalox ZX drone with camera 4k ,12 MP ,fly 3...          Mini Drone
# 1    Fitpro M3 Ultra Beginner Drone 2.4G Mini FPV H...          Mini Drone
# 2    Clubmall E88 Pro 4K Camera Drone with WiFi FPV...  Professional Drone
# 3    Orivox A17 Aerial Drone with 4K Dual Camera - ...          Mini Drone
# 4    Orivox M3 Max Mini Drone with Pro Features HD ...          Mini Drone
# ..                                                 ...                 ...
# 816  Swa Mi Drone WiFi Camera Remote Control-Motion...  Professional Drone
# 817                              Radhikadro e449 Drone  Professional Drone
# 818  Mevara fOlDaBlE-ToY-DrOnE pHoToGrApHy GeStUrE-...  Professional Drone
# 819  mayuri E8 WiFi Camera Remote Control 360 Flip ...  Professional Drone
# 820  Swa Mi E88 Drone Best Adults/Kids Drone With W...  Professional Drone
#
#      Weight    Price  Actual Price  Discount (%)        Model
# ...

# %%
Drone_data.columns
# Out:
# Index(['Name', 'Type', 'Control Range', 'Battery Type', 'Weight', 'Price',
#        'Actual Price', 'Discount (%)'],
#       dtype='object')

# %%
col_dict = {
    'Name': 'Drone_Name',
    'Type': 'Drone_Type',
    'Control Range': 'Control_Range',
    'Battery Type': 'Battery_Type',
    'Weight': 'Weight_g',
    'Price': 'Selling_Price',
    'Actual Price': 'Original_Price',
    'Discount (%)': 'Discount_Percent'
}

# %%
Drone_data = Drone_data.rename(columns = col_dict)
Drone_data.head(5)
# Out:
#                                           Drone_Name          Drone_Type  \
# 0  Zyamalox ZX drone with camera 4k ,12 MP ,fly 3...          Mini Drone
# 1  Fitpro M3 Ultra Beginner Drone 2.4G Mini FPV H...          Mini Drone
# 2  Clubmall E88 Pro 4K Camera Drone with WiFi FPV...  Professional Drone
# 3  Orivox A17 Aerial Drone with 4K Dual Camera - ...          Mini Drone
# 4  Orivox M3 Max Mini Drone with Pro Features HD ...          Mini Drone
#
#    Control_Range             Battery_Type  Weight_g  Selling_Price  \
# 0             40          Lithium Battery       200         2297.0
# 1            300               AA Battery       500        10255.0
# 2            102  AA Rechargeable Battery       150         1994.0
# 3             50          Lithium Battery       150         2455.0
# 4            200          Lithium Battery       200         4998.0
#
#    Original_Price  Discount_Percent
# 0          4999.0              54.0
# 1         11000.0               6.0
# ...

# %%
Drone_data.select_dtypes(include = 'object').head()
# Out:
#                                           Drone_Name          Drone_Type  \
# 0  Zyamalox ZX drone with camera 4k ,12 MP ,fly 3...          Mini Drone
# 1  Fitpro M3 Ultra Beginner Drone 2.4G Mini FPV H...          Mini Drone
# 2  Clubmall E88 Pro 4K Camera Drone with WiFi FPV...  Professional Drone
# 3  Orivox A17 Aerial Drone with 4K Dual Camera - ...          Mini Drone
# 4  Orivox M3 Max Mini Drone with Pro Features HD ...          Mini Drone
#
#               Battery_Type
# 0          Lithium Battery
# 1               AA Battery
# 2  AA Rechargeable Battery
# 3          Lithium Battery
# 4          Lithium Battery

# %%
Drone_data.select_dtypes(exclude = 'object').head()
# Out:
#    Control_Range  Weight_g  Selling_Price  Original_Price  Discount_Percent
# 0             40       200         2297.0          4999.0              54.0
# 1            300       500        10255.0         11000.0               6.0
# 2            102       150         1994.0          5999.0              66.0
# 3             50       150         2455.0          4999.0              50.0
# 4            200       200         4998.0          5999.0              16.0

# %%
Categorical_col = Drone_data.select_dtypes(include = 'object').columns
Categorical_col
# Out:
# Index(['Drone_Name', 'Drone_Type', 'Battery_Type'], dtype='object')

# %%
Numerical_col = Drone_data.select_dtypes(exclude = 'object').columns
Numerical_col
# Out:
# Index(['Control Range', 'Weight', 'Price', 'Actual Price', 'Discount (%)'], dtype='object')

# %%
cat_df = Drone_data.select_dtypes(include = 'object')
cat_df
# Out:
#                                                   Name                Type  \
# 0    Zyamalox ZX drone with camera 4k ,12 MP ,fly 3...          Mini Drone
# 1    Fitpro M3 Ultra Beginner Drone 2.4G Mini FPV H...          Mini Drone
# 2    Clubmall E88 Pro 4K Camera Drone with WiFi FPV...  Professional Drone
# 3    Orivox A17 Aerial Drone with 4K Dual Camera - ...          Mini Drone
# 4    Orivox M3 Max Mini Drone with Pro Features HD ...          Mini Drone
# ..                                                 ...                 ...
# 816  Swa Mi Drone WiFi Camera Remote Control-Motion...  Professional Drone
# 817                              Radhikadro e449 Drone  Professional Drone
# 818  Mevara fOlDaBlE-ToY-DrOnE pHoToGrApHy GeStUrE-...  Professional Drone
# 819  mayuri E8 WiFi Camera Remote Control 360 Flip ...  Professional Drone
# 820  Swa Mi E88 Drone Best Adults/Kids Drone With W...  Professional Drone
#
#                 Battery Type
# 0            Lithium Battery
# ...

# %%
Categorical_col = list(Drone_data.select_dtypes(include = 'object').columns)
Categorical_col
# Out:
# ['Name', 'Type', 'Battery Type']

# %%
Numerical_col = list(Drone_data.select_dtypes(exclude = 'object').columns)
Numerical_col
# Out:
# ['Control Range', 'Weight', 'Price', 'Actual Price', 'Discount (%)']

# %%
Drone_data.duplicated().any()
# Out:
# np.True_

# %%
Drone_data.duplicated().sum()
# Out:
# np.int64(3)

# %%
Drone_data.head(10)
# Out:
#                                                 Name                Type  \
# 0  Zyamalox ZX drone with camera 4k ,12 MP ,fly 3...          Mini Drone
# 1  Fitpro M3 Ultra Beginner Drone 2.4G Mini FPV H...          Mini Drone
# 2  Clubmall E88 Pro 4K Camera Drone with WiFi FPV...  Professional Drone
# 3  Orivox A17 Aerial Drone with 4K Dual Camera - ...          Mini Drone
# 4  Orivox M3 Max Mini Drone with Pro Features HD ...          Mini Drone
# 5  ERH India A17 Aerial Drone with 4K Dual Camera...          Mini Drone
# 6  Kidsbuddy New Good Quality Quadcopter E88 WIFI...          Mini Drone
# 7  tmwilla Foldable-RC-Quadcopter-Altitude-Hold-H...  Professional Drone
# 8  CLYSOL New Good Quality Quadcopter E88 WIFI Dr...          Mini Drone
# 9  Clubics RC Brushless Motor J18 Drone 4k hd Cam...  Professional Drone
#
#    Control Range             Battery Type  Weight    Price  Actual Price  \
# 0             40          Lithium Battery     200   2297.0        4999.0
# ...

# %%
Drone_data2 = Drone_data.drop_duplicates()

# %%
Drone_data2.shape
# Out:
# (818, 8)

# %%
Drone_data2.duplicated().any()
# Out:
# np.False_

# %%
#Indexing columns
df = Drone_data2.isnull().sum().reset_index()
#Rename column
df.columns = ['column', 'null_records']
#Create new colums and find out null value percentage
df['% null records'] = (df['null_records']/818)*100
df
# Out:
#           column  null_records  % null records
# 0           Name             0        0.000000
# 1           Type             0        0.000000
# 2  Control Range             0        0.000000
# 3   Battery Type             0        0.000000
# 4         Weight             0        0.000000
# 5          Price             8        0.977995
# 6   Actual Price             8        0.977995
# 7   Discount (%)            11        1.344743

# %%
Numerical_col = list(Drone_data.select_dtypes(exclude = 'object').columns)
Numerical_col
# Out:
# ['Control_Range',
#  'Weight_g',
#  'Selling_Price',
#  'Original_Price',
#  'Discount_Percent']

# %%
sell_mean = Drone_data2['Selling_Price'].mean()
sell_mean
# Out:
# np.float64(2983.3802469135803)

# %%
Drone_data2['Selling_Price'] = Drone_data2['Selling_Price'].fillna(sell_mean)
# Out:
# /tmp/ipykernel_8612/1563447485.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Drone_data2['Selling_Price'] = Drone_data2['Selling_Price'].fillna(sell_mean)

# %%
Drone_data2.isnull().sum()
# Out:
# Drone_Name           0
# Drone_Type           0
# Control_Range        0
# Battery_Type         0
# Weight_g             0
# Selling_Price        0
# Original_Price       8
# Discount_Percent    11
# dtype: int64

# %%
Org_mean = Drone_data2['Original_Price'].mean()
Org_mean
# Out:
# np.float64(8718.677777777777)

# %%
Drone_data2['Original_Price'] = Drone_data2['Original_Price'].fillna(Org_mean)
# Out:
# /tmp/ipykernel_8612/1997113637.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Drone_data2['Original_Price'] = Drone_data2['Original_Price'].fillna(Org_mean)

# %%
Drone_data2.isnull().sum()
# Out:
# Drone_Name           0
# Drone_Type           0
# Control_Range        0
# Battery_Type         0
# Weight_g             0
# Selling_Price        0
# Original_Price       0
# Discount_Percent    11
# dtype: int64

# %%
Dis_mean = Drone_data2['Discount_Percent'].mean()
Dis_mean
# Out:
# np.float64(63.87112763320942)

# %%
Drone_data2['Discount_Percent'] = Drone_data2['Discount_Percent'].fillna(Dis_mean)
# Out:
# /tmp/ipykernel_8612/1820459991.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Drone_data2['Discount_Percent'] = Drone_data2['Discount_Percent'].fillna(Dis_mean)

# %%
Drone_data2.isnull().sum()
# Out:
# Drone_Name          0
# Drone_Type          0
# Control_Range       0
# Battery_Type        0
# Weight_g            0
# Selling_Price       0
# Original_Price      0
# Discount_Percent    0
# dtype: int64
