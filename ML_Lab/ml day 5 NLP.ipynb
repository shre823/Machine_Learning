# %%
#NLTK (Natural Language Toolkit) is a popular Python library used for Natural Language Processing (NLP)—basically
#helping computers understand and work with human language.

# %%
# !pip install nltk

# %%
import nltk

# %%
#common datasets
nltk.download('punkt')        # for tokenization
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\hp\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# True

# %%
nltk.download('stopwords')   # for Stopword
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\hp\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# True

# %%
nltk.download('wordnet')     # for lemmatilization
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\hp\AppData\Roaming\nltk_data...
# True

# %%
nltk.download('averaged_perceptron_tagger')  # POS taggin
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\hp\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping taggers\averaged_perceptron_tagger.zip.
# True

# %%
nltk.download('movie_reviews') #for ml example later
# Out:
# [nltk_data] Downloading package movie_reviews to
# [nltk_data]     C:\Users\hp\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\movie_reviews.zip.
# True

# %%
print("nltk is successfully installed and ready to use!")
# Out:
# nltk is successfully installed and ready to use!

# %%
# step 2 : Tokenization

# %%
# Tokenization means breaking a sentenece into small parts

from nltk.tokenize import word_tokenize , sent_tokenize

text = "Natural Language Processing with NLTK is fun and educational. Let me learn in step by step!"

# sentence tokenization
sentence = sent_tokenize(text)
print("sentence tokenization:\n", sentence)

#word tokenization
word = word_tokenize(text)
print("word tokenization:\n", word)
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# Cell In[14], line 8
#       5 text = "Natural Language Processing with NLTK is fun and educational. Let me learn in step by step!"
#       7 # sentence tokenization
# ----> 8 sentence = sent_tokenize(text)
#       9 print("sentence tokenization:\n", sentence)
#      11 #word tokenization
#
# File ~\anaconda3\Lib\site-packages\nltk\tokenize\__init__.py:119, in sent_tokenize(text, language)
#     109 def sent_tokenize(text, language="english"):
#     110     """
#     111     Return a sentence-tokenized copy of *text*,
#     112     using NLTK's recommended sentence tokenizer
#    (...)    117     :param language: the model name in the Punkt corpus
#     118     """
# --> 119     tokenizer = _get_punkt_tokenizer(language)
#     120     return tokenizer.tokenize(text)
#
# ...

# %%
nltk.download('punkt_tab')        # for tokenization
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\hp\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt_tab.zip.
# True

# %%
# Tokenization means breaking a sentenece into small parts

from nltk.tokenize import word_tokenize , sent_tokenize

text = "Natural Language Processing with NLTK is fun and educational. Let me learn in step by step!"

# sentence tokenization
sentence = sent_tokenize(text)
print("sentence tokenization:\n", sentence)

#word tokenization
words = word_tokenize(text)
print("word tokenization:\n", word)
# Out:
# sentence tokenization:
#  ['Natural Language Processing with NLTK is fun and educational.', 'Let me learn in step by step!']
# word tokenization:
#  ['Natural', 'Language', 'Processing', 'with', 'NLTK', 'is', 'fun', 'and', 'educational', '.', 'Let', 'me', 'learn', 'in', 'step', 'by', 'step', '!']

# %%
# Remove stopword
# Stop words are common words like is , and , the which don't carry much meaning.
#Removing them helps models focusing on important word.

from nltk.corpus import stopwords

stop_words = set(stopwords.words('english'))

filtered_words = [w for w in words if w.lower() not in stop_words]

print("Words after removing stopwords:\n", filtered_words)
# Out:
# Words after removing stopwords:
#  ['Natural', 'Language', 'Processing', 'NLTK', 'fun', 'educational', '.', 'Let', 'learn', 'step', 'step', '!']

# %%
# Step 4: Stemming
# Stemming reduces a word to its base or root form.
# Example: running → run, studies → studi

from nltk.stem import PorterStemmer

stemmer = PorterStemmer()
stemmed_words = [stemmer.stem(w) for w in filtered_words]

print("Stemmed Words:\n", stemmed_words)
# Out:
# Stemmed Words:
#  ['natur', 'languag', 'process', 'nltk', 'fun', 'educ', '.', 'let', 'learn', 'step', 'step', '!']

# %%
# Step 5: Lemmatization
# Lemmatization is similar to stemming but more accurate and returns real words.
# It uses the WordNet dictionary.

from nltk.stem import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()
lemmatized_words = [lemmatizer.lemmatize(w) for w in filtered_words]

print("Lemmatized Words:\n", lemmatized_words)
# Out:
# Lemmatized Words:
#  ['Natural', 'Language', 'Processing', 'NLTK', 'fun', 'educational', '.', 'Let', 'learn', 'step', 'step', '!']

# %%
import nltk
nltk.download('averaged_perceptron_tagger_eng')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     C:\Users\hp\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping taggers\averaged_perceptron_tagger_eng.zip.
# True

# %%
# Step 6: Part of Speech (POS) Tagging
# POS tagging identifies whether a word is a noun, verb, adjective, etc.
# This helps in understanding the grammatical structure of text.

pos_tags = nltk.pos_tag(filtered_words)
print("Part of Speech Tagging:\n", pos_tags)
# Out:
# Part of Speech Tagging:
#  [('Natural', 'JJ'), ('Language', 'NNP'), ('Processing', 'NNP'), ('NLTK', 'NNP'), ('fun', 'VBD'), ('educational', 'JJ'), ('.', '.'), ('Let', 'VB'), ('learn', 'JJ'), ('step', 'VB'), ('step', 'NN'), ('!', '.')]

# %%
# Step 7: Frequency Distribution
# Frequency Distribution helps count how many times each word appears.

from nltk import FreqDist

freq_dist = FreqDist(filtered_words)
print("Word Frequency:")
for word, freq in freq_dist.most_common(5):  # show top 5
    print(f"{word}: {freq}")

# Plot word frequency
freq_dist.plot(10, title="Top 10 Word Frequencies")
# Out:
# Word Frequency:
# step: 2
# Natural: 1
# Language: 1
# Processing: 1
# NLTK: 1
# <Axes: title={'center': 'Top 10 Word Frequencies'}, xlabel='Samples', ylabel='Counts'>

# %%
# Simple Text Classification Example
# Let's classify movie reviews (positive or negative) using NLTK's dataset.
# This shows how NLTK is connected to Machine Learning.

import random
from nltk.corpus import movie_reviews

# Load dataset
documents = [(list(movie_reviews.words(fileid)), category)
             for category in movie_reviews.categories()
             for fileid in movie_reviews.fileids(category)]

# Shuffle data for randomness
random.shuffle(documents)

# Extract all words and find frequency
all_words = nltk.FreqDist(w.lower() for w in movie_reviews.words())
word_features = list(all_words)[:2000] # top 2000 words as features

def find_features(document):
    words = set(document)
    features = {}
    for w in word_features:
        features[w] = (w in words)
    return features

# Prepare training data
featuresets = [(find_features(rev), category) for (rev, category) in documents]

# Split into train and test
train_set, test_set = featuresets[100:], featuresets[:100]

# Train a simple Naive Bayes Classifier
classifier = nltk.NaiveBayesClassifier.train(train_set)

# Test accuracy
accuracy = nltk.classify.accuracy(classifier, test_set) * 100
print(f"Classifier Accuracy: {accuracy:.2f}%")

# Show most informative features
classifier.show_most_informative_features(10)
# Out:
# Classifier Accuracy: 85.00%
# Most Informative Features
#              outstanding = True              pos : neg    =     10.9 : 1.0
#                    mulan = True              pos : neg    =      8.3 : 1.0
#                   seagal = True              neg : pos    =      7.8 : 1.0
#              wonderfully = True              pos : neg    =      7.2 : 1.0
#                    damon = True              pos : neg    =      5.9 : 1.0
#               ridiculous = True              neg : pos    =      5.7 : 1.0
#                   wasted = True              neg : pos    =      5.6 : 1.0
#                    flynt = True              pos : neg    =      5.6 : 1.0
#                     lame = True              neg : pos    =      5.3 : 1.0
#                    waste = True              neg : pos    =      5.0 : 1.0
